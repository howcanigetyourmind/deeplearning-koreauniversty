# %% [markdown]
# <a href="https://colab.research.google.com/github/howcanigetyourmind/deeplearning-koreauniversty/blob/master/NeuralStyle_%EC%8B%A4%EC%8A%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y scipy
# !pip install        scipy==1.1.0
import scipy
scipy.__version__
# Out:
# Uninstalling scipy-1.3.0:
#   Successfully uninstalled scipy-1.3.0
# ...
#      |████████████████████████████████| 31.2MB 65.2MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
# '1.1.0'

# %%
# %cd /content
# !rm -rf neural-style
# !git clone https://github.com/howcanigetyourmind/neural-style.git -
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# %cd /content/neural-style
# !ls
# Out:
# /content
# Cloning into '-'...
# remote: Enumerating objects: 288, done.
# remote: Total 288 (delta 0), reused 0 (delta 0), pack-reused 288
# Receiving objects: 100% (288/288), 2.63 MiB | 28.01 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
# --2019-07-25 12:15:52--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat.1’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  37.7MB/s    in 14s
#
# 2019-07-25 12:16:07 (36.3 MB/s) - ‘imagenet-vgg-verydeep-19.mat.1’ saved [534904783/534904783]
#
# [Errno 2] No such file or directory: '/content/neural-style'
# /content
# -  imagenet-vgg-verydeep-19.mat  imagenet-vgg-verydeep-19.mat.1  sample_data

# %%
# !wget http://image.chosun.com/sitedata/image/201803/29/2018032902251_0.jpg
# !ls 2018032902251_0.jpg
# !cd /content/neural-style
# !wget http://www.catholicworker.kr/news/photo/201801/1915_4157_5622.jpg
# !ls 1915_4157_5622.jpg
!%cd /content/neural-style
# Out:
# --2019-07-25 12:17:51--  http://image.chosun.com/sitedata/image/201803/29/2018032902251_0.jpg
# Resolving image.chosun.com (image.chosun.com)... 13.35.115.34, 13.35.115.41, 13.35.115.73, ...
# Connecting to image.chosun.com (image.chosun.com)|13.35.115.34|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 166512 (163K) [image/jpeg]
# Saving to: ‘2018032902251_0.jpg.2’
#
# 2018032902251_0.jpg 100%[===================>] 162.61K  --.-KB/s    in 0.08s
#
# 2019-07-25 12:17:52 (2.03 MB/s) - ‘2018032902251_0.jpg.2’ saved [166512/166512]
#
# 2018032902251_0.jpg
# /bin/bash: line 0: cd: /content/neural-style: No such file or directory
# --2019-07-25 12:17:56--  http://www.catholicworker.kr/news/photo/201801/1915_4157_5622.jpg
# Resolving www.catholicworker.kr (www.catholicworker.kr)... 121.125.77.244
# Connecting to www.catholicworker.kr (www.catholicworker.kr)|121.125.77.244|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("2018032902251_0.jpg")
plt.imshow(img)
plt.show()
