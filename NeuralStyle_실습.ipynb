# %% [markdown]
# <a href="https://colab.research.google.com/github/howcanigetyourmind/deeplearning-koreauniversty/blob/master/NeuralStyle_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y scipy
# !pip install        scipy==1.1.0
import scipy
scipy.__version__
# Out:
# Uninstalling scipy-1.3.0:
#   Successfully uninstalled scipy-1.3.0
# ...
#      |████████████████████████████████| 31.2MB 87.6MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
# '1.1.0'

# %%
# %cd /content
# !rm -rf neural-style
# !git clone https://github.com/howcanigetyourmind/neural-style.git 
# %cd /content/neural-style
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat 

# !ls
# Out:
# /content
# Cloning into 'neural-style'...
# remote: Enumerating objects: 288, done.
# remote: Total 288 (delta 0), reused 0 (delta 0), pack-reused 288
# Receiving objects: 100% (288/288), 2.63 MiB | 15.28 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
# /content/neural-style
# --2019-07-25 12:34:04--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  65.8MB/s    in 8.1s
#
# 2019-07-25 12:34:12 (63.4 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]
#
# examples		      LICENSE.txt      README.md	 stylize.py
# imagenet-vgg-verydeep-19.mat  neural_style.py  requirements.txt  vgg.py

# %%
# !ls -alsh *.mat
# Out:
# 511M -rw-r--r-- 1 root root 511M Sep 30  2016 imagenet-vgg-verydeep-19.mat

# %%
# !pwd
# !ls examples*
# Out:
# /content/neural-style
# 1-content.jpg  1-style.jpg    2-output.jpg  2-style2.jpg
# 1-output.jpg   2-content.jpg  2-style1.jpg  tweaks

# %%
# !python /content/neural-style/neural_style.py                                          \
        --content /content/neural-style/examples/2-content.jpg  \
        --styles  /content/neural-style/examples/2-style1.jpg   \
        --output  /content/neural-style/out.jpg
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 12:34:29.453611 140164059330432 deprecation_wrapper.py:119] From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0725 12:34:29.454035 140164059330432 deprecation_wrapper.py:119] From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-07-25 12:34:29.502936: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-07-25 12:34:29.504894: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x15a32c0 executing computations on platform Host. Devices:
# 2019-07-25 12:34:29.504948: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-07-25 12:34:29.513941: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
#Markdown으로 보면 좀 쉽게 볼 수 있음.
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("out.jpg")
plt.imshow(img)
plt.show()

# %%
# !find/content/ iname "*py" |xargs grep -ni "scipy"
# Out:
# /bin/bash: find/content/: No such file or directory
